# %% [markdown]
# Zadání
# Stáhni si soubor platy_2021_02.csv s informacemi o platech v softwarové firmě (stejný soubor, jako v předchozím úkolu).
#
# Načti si tato data do tabulky a vytvoř histogram. Nastav vhodně hranice skupin histogramu (parametr bins), aby byl graf přehledný a snadno interpretovatelný.

# %%
import pandas

# %%
platy_2021 = pandas.read_csv("platy_2021_02.csv")
platy_2021.set_index("cislo_zamestnance", inplace = True)
platy_2021
# Out:
#                       plat
# cislo_zamestnance
# 3                  54900.0
# 6                  54800.0
# 7                  36400.0
# 8                  47900.0
# 16                 34200.0
# 18                 35400.0
# 21                 54200.0
# 22                 34400.0
# 23                 39000.0
# 24                 44200.0
# 26                 59600.0
# 27                 45100.0
# 28                 38100.0
# 29                 48900.0
# 30                 33500.0
# 32                 53000.0
# 33                 38400.0
# 34                 36800.0
# 38                 32600.0
# 40                 32800.0
# 41                 49300.0
# 44                 52000.0
# 47                 40700.0
# 49                 58400.0
# 51                 37100.0
# 56                 39300.0
# 57                 36800.0
# 63                 31400.0
# 64                 36900.0
# 69                 32600.0
# 70                 52600.0
# 74                 49300.0
# ...

# %%
histogram = platy_2021['plat'].plot(kind='hist', bins=15, grid=True)
histogram.set_title("Přehled platů zaměstnanců v softwarové firmě za rok 2021")
histogram.set_ylabel("zaměstnanci")
histogram.set_xlabel("platy")
# Out:
# Text(0.5, 0, 'platy')

# %% [markdown]
# Vrať se k práci se souborem temperature.csv, který obsahuje informace o průměrné teplotě v různých městech v listopadu 2017.
#
# Vytvoř tabulku, která bude obsahovat údaje o teplotě za města Helsinki, Miami Beach a Tokyo.
# Vytvoř krabicový graf a porovnej rozsah teplot v těchto městech.

# %%
teploty = pandas.read_csv("temperature.csv")

# %%
helsinki = teploty[teploty["City"] == "Helsinki"]
miami = teploty[teploty["City"] == "Miami Beach"]
tokyo = teploty[teploty["City"] == "Tokyo"]

# %%
srovnani = pandas.concat([helsinki, miami, tokyo], ignore_index=True)
srovnani
# Out:
#     Region  Country      City  Day  AvgTemperature
# 0   Europe  Finland  Helsinki    1            29.6
# 1   Europe  Finland  Helsinki    2            29.5
# 2   Europe  Finland  Helsinki    3            35.1
# 3   Europe  Finland  Helsinki    4            44.5
# 4   Europe  Finland  Helsinki    5            45.5
# ..     ...      ...       ...  ...             ...
# 85    Asia    Japan     Tokyo   26            58.8
# 86    Asia    Japan     Tokyo   27            53.8
# 87    Asia    Japan     Tokyo   28            53.8
# 88    Asia    Japan     Tokyo   29            58.4
# 89    Asia    Japan     Tokyo   30            51.5
#
# [90 rows x 5 columns]

# %%
srovnani.plot(kind='box', whis=[0, 100], by="City", column = "AvgTemperature")
# Out:
# AvgTemperature    Axes(0.125,0.11;0.775x0.77)
# dtype: object
